# %%
import time  
   
import webbrowser 

d=time.strftime("%a", time.localtime())
Actual_Time = time.strftime("%H:%M:%S",time.localtime())
h=int(time.strftime("%H",time.localtime()))
m=int(time.strftime("%M",time.localtime()))
s=int(time.strftime("%S",time.localtime()))
i=0
print("Hey! Do you want me to automatically join your today's zoom meetings ??")
ans=input(" Y/N : ")

if ans == "N":
    print("OK bye, feel free to use me anytime :)")
    
elif d == "Sat" or d == "Sun" and ans == "Y":
    print("CHILL, its a weekend! You have no meetings today.")
    
elif d == "Mon" and ans == "Y":
    set_alarm=["08:53:00","09:43:00","10:34:00", "13:54:00", "15:34:00"]
    url=["https://tiet.zoom.us/my/eied2", "https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/eced11", "https://tiet.zoom.us/my/mee01"]
    
    while not(h >=15 and m>=34 and s>=3):
        if (Actual_Time == set_alarm[i]):
            print ("You should join your", i+1, "meeting now :-)")
            webbrowser.open(url[i])
            time.sleep(1)
        Actual_Time = time.strftime("%H:%M:%S",time.localtime())
        h=int(time.strftime("%H",time.localtime()))
        m=int(time.strftime("%M",time.localtime()))
        s=int(time.strftime("%S",time.localtime()))
        i=(i+1)%5
        
elif d == "Tue" and ans == "Y":
    set_alarm=["08:53:00","09:42:00","11:22:00", "12:22:00", "15:34:00"]
    url=["https://web.whatsapp.com/", "https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/mee01", "https://tiet.zoom.us/my/eied2", "https://tiet.zoom.us/my/CSED11"]
    
    while not(h >=15 and m>=34 and s>=5):
        if (Actual_Time == set_alarm[i]):
            print ("You should join your", i+1 , "meeting now :-)")
            webbrowser.open(url[i])
            time.sleep(1)
        Actual_Time = time.strftime("%H:%M:%S",time.localtime())
        h=int(time.strftime("%H",time.localtime()))
        m=int(time.strftime("%M",time.localtime()))
        s=int(time.strftime("%S",time.localtime()))
        i=(i+1)%5

elif d == "Wed" and ans == "Y":
    set_alarm=["08:53:00","09:42:00","10:33:00", "11:23:00", "14:44:00"]
    url=["https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/eied2", "https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/eied1"]
    
    while not(h >=14 and m>=44 and s>=5):
        if (Actual_Time == set_alarm[i]):
            print ("You should join your", i+1, " meeting now :-)")
            webbrowser.open(url[i])
            time.sleep(1)
        Actual_Time = time.strftime("%H:%M:%S",time.localtime())
        h=int(time.strftime("%H",time.localtime()))
        m=int(time.strftime("%M",time.localtime()))
        s=int(time.strftime("%S",time.localtime()))
        i=(i+1)%5
        
elif d == "Thur" and ans == "Y":
    set_alarm=["09:43:00","11:22:00","13:54:00", "15:32:00", "16:23:00"]
    url=["https://tiet.zoom.us/my/CSED9", "https://tiet.zoom.us/my/CSED7", "https://tiet.zoom.us/my/CSED8", "https://tiet.zoom.us/my/CSED9", "https://tiet.zoom.us/my/CSED9"]
    
    while not(h >=16 and m>=23 and s>=5):
        if (Actual_Time == set_alarm[i]):
            print ("You should join your", i+1, " meeting now :-)")
            webbrowser.open(url[i])
            time.sleep(1)
        Actual_Time = time.strftime("%H:%M:%S",time.localtime())
        h=int(time.strftime("%H",time.localtime()))
        m=int(time.strftime("%M",time.localtime()))
        s=int(time.strftime("%S",time.localtime()))
        i=(i+1)%5

elif d == "Fri" and ans == "Y":
    set_alarm=["20:59:40","20:59:55","21:01:10", "21:02:00", "21:03:00"]
    url=["https://web.whatsapp.com/", "www.google.com", "www.facebook.com", "www.instagram.com", "www.youtube.com"]
    
    while not(h >=21 and m>=3 and s>=5):
        if (Actual_Time == set_alarm[i]):
            print ("You should join your", i+1, " meeting now :-)")
            webbrowser.open(url[i])
            time.sleep(1)
        Actual_Time = time.strftime("%H:%M:%S",time.localtime())
        h=int(time.strftime("%H",time.localtime()))
        m=int(time.strftime("%M",time.localtime()))
        s=int(time.strftime("%S",time.localtime()))
        i=(i+1)%5
else:
    print("Not valid, try next time")
# Out:
# Hey! Do you want me to automatically join your today's zoom meetings ??
#  Y/N : Y
# You should join your 1  meeting now :-)
# You should join your 2  meeting now :-)
# You should join your 3  meeting now :-)
# You should join your 4  meeting now :-)
# You should join your 5  meeting now :-)
